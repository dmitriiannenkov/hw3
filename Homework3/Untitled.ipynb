# %%
# Homework 3
# Dmitrii Annenkov

# %% [markdown]
# This homework aims to predict customer default status payments in Taiwan.
# - Use Naïve Bayes to predict the customer default status.
# - Use Neural Network to Predict customers default status.

# %%
## Import Library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_excel('')

df = pd.read_excel (r'Desktop/Machine Learning Class/Homework3/default_of_credit_card_clients.xls')
print (df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/yv/4ng2rnns3nn8ynp131yyfk9m0000gn/T/ipykernel_3437/3061650547.py in <module>
# ----> 1 df = pd.read_excel('')
#       2
#       3 df = pd.read_excel (r'Desktop/Machine Learning Class/Homework3/default_of_credit_card_clients.xls')
#       4 print (df)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
